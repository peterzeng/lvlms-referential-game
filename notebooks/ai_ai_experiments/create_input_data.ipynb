# %%
# %load_ext autoreload
# %autoreload 2

import os

os.chdir("../../")

# %%
from src.data.image_utils import matplotlib_image_grid

# %%
grids_presets5 = {
  "rounds": [
    {
      "round": 1,
      "baskets": [
        "076.png", "001.png", "015.png", "009.png", "022.png", "033.png",
        "012.png", "040.png", "037.png", "019.png", "065.png", "017.png"
      ]
    },
    {
      "round": 2,
      "baskets": [
        "015.png", "037.png", "001.png", "022.png", "040.png", "076.png",
        "033.png", "019.png", "012.png", "065.png", "009.png", "017.png"
      ]
    },
    {
      "round": 3,
      "baskets": [
        "012.png", "009.png", "033.png", "076.png", "017.png", "037.png",
        "001.png", "040.png", "022.png", "065.png", "019.png", "015.png"
      ]
    },
    {
      "round": 4,
      "baskets": [
        "019.png", "022.png", "076.png", "012.png", "065.png", "001.png",
        "037.png", "015.png", "033.png", "009.png", "017.png", "040.png"
      ]
    },
    {
      "fullList": [
        "076.png", "001.png", "015.png", "009.png", "022.png", "033.png",
        "012.png", "040.png", "037.png", "019.png", "065.png", "017.png",
        "005.png", "039.png", "057.png", "081.png", "077.png", "078.png"
      ]
    }
  ]
}

image_dir = "data/images"
grid_image_dir = "data/grid_images/presets5/"
os.makedirs(grid_image_dir, exist_ok=True)

for preset in grids_presets5["rounds"]:
    if "baskets" in preset:
        round_num = preset["round"]
        basket_filenames = preset["baskets"]
        basket_image_paths = [os.path.join(image_dir, fn) for fn in basket_filenames]
        grid_image_fp = os.path.join(grid_image_dir, f"director_round_{round_num}.png")
        matplotlib_image_grid(basket_image_paths, (2, 6), save_path=grid_image_fp)
    
    elif "fullList" in preset:
        basket_filenames = preset["fullList"]
        basket_image_paths = [os.path.join(image_dir, fn) for fn in basket_filenames]
        grid_image_fp = os.path.join(grid_image_dir, f"matcher.png")
        matplotlib_image_grid(basket_image_paths, (3, 6), save_path=grid_image_fp)
